# %%
import random
import calendar
import time
import math
import numpy as np

origintime=0
max_policies=10
max_policy_changes=3
#max_policy_length=365*24*3600
max_policy_length=3600
policy_vars=[3,8]
#policy_m_init=11
#policy_sd_init=4.2
policy_m_init=4
policy_sd_init=1.5


baseclaimrate=1.2
claim_rates=[0.1,0.2]
claim_report_m=11
claim_report_sd=3
claim_payment_rate=1.3

payment_m=9
payment_sd=4
payment_time_delay_m=3
payment_time_delay_sd=1.5


max_claims=1
max_periods=3
max_class=3
max_customer_changes=2

#All timelines are calendar
#Sendingtimes are random, but after origintime

class Sample:
    def __init__(self,polnr):
        self.policies(polnr)
        self.customers()
        self.claims()
        self.combine()
        
    def customers(self):
        times=[p["policystarttime"] for p in self.policy]
        self.customer=[]
        self.customer.append({"customer":"cust"+str(self.policy[0]["policy"]),"customertime":self.policy[0]["policystarttime"],"address":"Here"})
        r=random.sample(times,1)[0]
        if r!=times[0]:
             self.customer.append({"customer":"cust"+str(self.policy[0]["policy"]),"customertime":r,"address":"There"})
        
    def policies(self,polnr):
        #Only one policy is made
        self.policy=[]
        policynr=random.randint(1,max_policies)
        if polnr>0:
            policynr=polnr
        lasttime=origintime+random.lognormvariate(policy_m_init,policy_sd_init)
        for _ in range(random.randint(1,max_policy_changes)):
            newtime=random.uniform(lasttime,lasttime+max_policy_length)
            newpolicy={"policy":policynr,"policystarttime":lasttime,"policyendtime":newtime}
            lasttime=newtime
            ci=0
            for i in policy_vars:
                newpolicy[str("pvar"+str(ci))]=random.sample(set(range(i)),1)[0]
                ci=ci+1
            self.policy.append(newpolicy)

    def claims(self):
        self.claim=[]
        self.claimpayment=[]
        times=[p["policystarttime"] for p in self.policy]
        claimpayment=[]
        claimcount=0
        for ci in range(len(self.policy)):
            rate=baseclaimrate
            for i in range(len(policy_vars)):
                rate=rate+claim_rates[i]*self.policy[ci][str("pvar"+str(i))]
            mu=rate*(float(self.policy[ci]["policyendtime"])-float(self.policy[ci]["policystarttime"]))
            mu=mu/max_policy_length
            claimcounts=math.floor(random.expovariate(1/mu))
            lastclaimtime=self.policy[ci]["policystarttime"]
            for c in range(claimcounts):
                claimtime=random.uniform(lastclaimtime,self.policy[ci]["policyendtime"])
                claimreporttime=claimtime+random.lognormvariate(claim_report_m,claim_report_sd)
                lastclaimtime=claimtime
                claimnumber=str(self.policy[0]["policy"])+"_"+str(claimcount)
                self.claim.append({"claimnumber":claimnumber,"claimtime":claimtime,"claimreporttime":claimreporttime,"claimcounter":claimcount})
                claimcount=claimcount+1
                mupayments=claim_payment_rate
                countpayments=math.floor(random.expovariate(1/mupayments))
                #print("countpayments is "+str(countpayments))
                lastpaytime=self.claim[c]["claimreporttime"]
                for pay in range(countpayments):
                    amount=random.lognormvariate(payment_m,payment_sd)
                    paytime=lastpaytime+random.lognormvariate(payment_time_delay_m,payment_time_delay_sd)
                    lastpaytime=paytime
                    self.claimpayment.append({"claimnumber":self.claim[c]["claimnumber"],"claimcounter":self.claim[c]["claimcounter"],"paytime":paytime,"payment":amount})

    def combine(self):
        self.data={"customer":self.customer,"policy":self.policy,"claim":self.claim,"payment":self.claimpayment}
        
    def tolist(self):
        s=[]
        for c in self.customer:
            s.append({'type':'customer','value':c})
        for c in self.policy:
            s.append({'type':'policy','value':c})
        for c in self.claim:
            s.append({'type':'claim','value':c})
        for c in self.claimpayment:
            s.append({'type':'claimpayment','value':c})
        s.append({'type':'total','value':self.data})
        return(s)
        
    def reportdata(self,a):
        #create random delays for all stuff, then combine
        if isinstance(a,dict):
            for k in a.keys():
                print(k)

    def recordsinint(self,fra,til):
        newcustomer=[c for c in self.customer if c["customertime"]<til and c["customertime"]>=fra]
        newpolicy=[c for c in self.policy if c["policystarttime"]<til and c["policystarttime"]>=fra]
        newclaim=[c for c in self.claim if c["claimreporttime"]<til and c["claimreporttime"]>=fra]
        newclaimpayment=[c for c in self.claimpayment if c["paytime"]<til and c["paytime"]>=fra]
        self.newdata={"customer":newcustomer,"policy":newpolicy,"claim":newclaim,"payment":newclaimpayment}
        
    def print(self):
        #print(self.customer)
        #print("\n")
        #print(self.policy)
        #print("\n")
        #print(self.claim)
        #print("\n")
        #print(self.claimpayment)
        print(self.data)

# %%
# !pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /anaconda/envs/py35/lib/python3.5/site-packages

# %%
from kafka import KafkaProducer
from kafka.errors import KafkaError
import json
import re
import random

# %%
s=[]
for i in range(3):
    d=Sample(i)
    a=d.tolist()
    s=s+a
    
random.shuffle(s)

for ss in s:
    if ss['type']=='customer':
        print('customer')
        #print(ss['value'])
    if ss['type']=='policy':
        print('policy')
    if ss['type']=='claim':
        print('claim')
    if ss['type']=='claimpayment':
        print('claimpayment')
    if ss['type']=='total':
        print('total')
        print(ss['value'])
# Out:
# claim
# policy
# claimpayment
# claimpayment
# customer
# claim
# total
# {'claim': [{'claimnumber': '1_0', 'claimcounter': 0, 'claimtime': 5802.052446582833, 'claimreporttime': 9343.582380677231}, {'claimnumber': '1_1', 'claimcounter': 1, 'claimtime': 7127.343911279381, 'claimreporttime': 1551237.0980209578}], 'payment': [{'claimnumber': '1_0', 'payment': 2632086.624681557, 'paytime': 9360.40559191066, 'claimcounter': 0}, {'claimnumber': '1_0', 'payment': 11905.98914776887, 'paytime': 9619.38863055942, 'claimcounter': 0}, {'claimnumber': '1_0', 'payment': 4256.121877079475, 'paytime': 9677.506228088178, 'claimcounter': 0}, {'claimnumber': '1_0', 'payment': 270.03296020742647, 'paytime': 9704.022527707588, 'claimcounter': 0}, {'claimnumber': '1_0', 'payment': 4078.8933447369864, 'paytime': 9707.37790469098, 'claimcounter': 0}, {'claimnumber': '1_0', 'payment': 3633740.3044643374, 'paytime': 9714.242842084705, 'claimcounter': 0}, {'claimnumber': '1_0', 'payment': 253624.2116174221, 'paytime': 9716.415153577454, 'claimcounter': 0}, {'claimnumber': '1_0', 'payment': 7611.5202776684855, 'paytime': 9778.147551295662, 'claimcounter': 0}, {'claimnumber': '1_1', 'payment': 484.8597276458526, 'paytime': 1551238.462611534, 'claimcounter': 1}], 'customer': [{'customer': 'cust1', 'customertime': 37.518455311266095, 'address': 'Here'}], 'policy': [{'pvar0': 2, 'policystarttime': 37.518455311266095, 'policyendtime': 2440.8918434532584, 'policy': 1, 'pvar1': 1}, {'pvar0': 0, 'policystarttime': 2440.8918434532584, 'policyendtime': 4004.0879606812296, 'policy': 1, 'pvar1': 6}, {'pvar0': 1, 'policystarttime': 4004.0879606812296, 'policyendtime': 7145.708676484386, 'policy': 1, 'pvar1': 6}]}
# claimpayment
# claim
# claimpayment
# policy
# customer
# total
# {'claim': [], 'payment': [], 'customer': [{'customer': 'cust2', 'customertime': 183.25141843681428, 'address': 'Here'}, {'customer': 'cust2', 'customertime': 2027.7484629318255, 'address': 'There'}], 'policy': [{'pvar0': 0, 'policystarttime': 183.25141843681428, 'policyendtime': 2027.7484629318255, 'policy': 2, 'pvar1': 7}, {'pvar0': 0, 'policystarttime': 2027.7484629318255, 'policyendtime': 3236.674842236725, 'policy': 2, 'pvar1': 5}, {'pvar0': 1, 'policystarttime': 3236.674842236725, 'policyendtime': 5468.699855989769, 'policy': 2, 'pvar1': 0}]}
# claim
# claimpayment
# claimpayment
# policy
# policy
# claim
# claimpayment
# total
# {'claim': [{'claimnumber': '8_0', 'claimcounter': 0, 'claimtime': 757.0958588134466, 'claimreporttime': 763.9988432683933}, {'claimnumber': '8_1', 'claimcounter': 1, 'claimtime': 1961.0789794904226, 'claimreporttime': 187146.37408528037}, {'claimnumber': '8_2', 'claimcounter': 2, 'claimtime': 2009.0166876247126, 'claimreporttime': 9965.896049130712}, {'claimnumber': '8_3', 'claimcounter': 3, 'claimtime': 2032.8022241760293, 'claimreporttime': 5550.850374850734}, {'claimnumber': '8_4', 'claimcounter': 4, 'claimtime': 2080.7929987142925, 'claimreporttime': 26745977.80982167}, {'claimnumber': '8_5', 'claimcounter': 5, 'claimtime': 2082.2621799611034, 'claimreporttime': 394689.1284262073}], 'payment': [], 'customer': [{'customer': 'cust8', 'customertime': 6.589747516822801, 'address': 'Here'}], 'policy': [{'pvar0': 0, 'policystarttime': 6.589747516822801, 'policyendtime': 2082.7449254896324, 'policy': 8, 'pvar1': 4}, {'pvar0': 0, 'policystarttime': 2082.7449254896324, 'policyendtime': 3786.675123578686, 'policy': 8, 'pvar1': 4}]}
# policy
# customer
# policy
# customer
# claimpayment
# claim
# policy
# claim
# claimpayment
# claim
# policy

# %%
#producer = KafkaProducer(value_serializer=lambda m: json.dumps(m).encode('ascii'),key_serializer=lambda m: json.dumps(m).encode('ascii'),bootstrap_servers=['10.101.12.4:9092'])

for i in range(22):
    print("Sample nr "+str(i))
    d=Sample(i)
    data_customer=d.customer[0]
    data_policy=d.policy[0]
    data_claim=d.claim
    data_claimpayment=d.claimpayment
    data_customer_key=int(re.findall(r'\d+',data_customer['customer'])[0])
    #cust={'key':re.findall(r'\d+',data_customer['customer'])[0],'value':data_customer}
    #producer.send('customer1', key=data_customer_key,value=data_customer)
    print(data_customer)
    print(d.customer)
    #data_policy_key=re.findall(r'\d+',data_policy['policy'])[0]
    data_policy_key=data_policy['policy']
    #producer.send('policy1', key=data_policy_key,value=data_policy)
    #producer.send('policy1', data_policy)
    #print(data_policy)
    if len(data_claim)>0:
        #print("claim")
        data_claim_key=int(re.findall(r'[\d+]*',data_claim[0]['claimnumber'])[0])
        #print(data_claim[0])
        #print(data_claim_key)
        #producer.send('claim1', key=data_claim_key,value=data_claim)
        #producer.send('claim1', data_claim[0])
    if len(data_claimpayment)>0:
        data_claimpayment_key=int(re.findall(r'[\d+]*',data_claimpayment[0]['claimnumber'])[0])
        #print("payment")
        #print(data_claimpayment[0])
        #producer.send('claim1', key=data_claim_key,value=data_claim)
        #producer.send('claimpayment1', data_claimpayment[0])
    print("Total")
    #producer.send('total1', d.data)
    #producer.flush()
# Out:
# Sample nr 0
# {'customer': 'cust6', 'customertime': 22.672061318482214, 'address': 'Here'}
# [{'customer': 'cust6', 'customertime': 22.672061318482214, 'address': 'Here'}]
# Total
# Sample nr 1
# {'customer': 'cust1', 'customertime': 32.22142661746492, 'address': 'Here'}
# [{'customer': 'cust1', 'customertime': 32.22142661746492, 'address': 'Here'}]
# Total
# Sample nr 2
# {'customer': 'cust2', 'customertime': 68.97755003728074, 'address': 'Here'}
# [{'customer': 'cust2', 'customertime': 68.97755003728074, 'address': 'Here'}]
# Total
# Sample nr 3
# {'customer': 'cust3', 'customertime': 63.06750603705334, 'address': 'Here'}
# [{'customer': 'cust3', 'customertime': 63.06750603705334, 'address': 'Here'}]
# Total
# Sample nr 4
# {'customer': 'cust4', 'customertime': 254.29118903087158, 'address': 'Here'}
# [{'customer': 'cust4', 'customertime': 254.29118903087158, 'address': 'Here'}]
# Total
# Sample nr 5
# {'customer': 'cust5', 'customertime': 12.121649491837305, 'address': 'Here'}
# [{'customer': 'cust5', 'customertime': 12.121649491837305, 'address': 'Here'}]
# Total
# Sample nr 6
# {'customer': 'cust6', 'customertime': 265.09934805279465, 'address': 'Here'}
# [{'customer': 'cust6', 'customertime': 265.09934805279465, 'address': 'Here'}]
# Total
# Sample nr 7
# {'customer': 'cust7', 'customertime': 53.81000016294401, 'address': 'Here'}
# [{'customer': 'cust7', 'customertime': 53.81000016294401, 'address': 'Here'}, {'customer': 'cust7', 'customertime': 4385.6264134490175, 'address': 'There'}]
# Total
# Sample nr 8
# {'customer': 'cust8', 'customertime': 7.722871688273783, 'address': 'Here'}
# [{'customer': 'cust8', 'customertime': 7.722871688273783, 'address': 'Here'}, {'customer': 'cust8', 'customertime': 1113.2288376206968, 'address': 'There'}]
# Total
# Sample nr 9
# {'customer': 'cust9', 'customertime': 161.49618015433074, 'address': 'Here'}
# [{'customer': 'cust9', 'customertime': 161.49618015433074, 'address': 'Here'}]
# Total
# Sample nr 10
# {'customer': 'cust10', 'customertime': 113.79185906064713, 'address': 'Here'}
# [{'customer': 'cust10', 'customertime': 113.79185906064713, 'address': 'Here'}, {'customer': 'cust10', 'customertime': 156.74933928328443, 'address': 'There'}]
# Total
# Sample nr 11
# {'customer': 'cust11', 'customertime': 373.39866106312104, 'address': 'Here'}
# [{'customer': 'cust11', 'customertime': 373.39866106312104, 'address': 'Here'}, {'customer': 'cust11', 'customertime': 2980.158702439142, 'address': 'There'}]
# Total
# Sample nr 12
# {'customer': 'cust12', 'customertime': 535.778076692244, 'address': 'Here'}
# [{'customer': 'cust12', 'customertime': 535.778076692244, 'address': 'Here'}, {'customer': 'cust12', 'customertime': 1191.9268176301387, 'address': 'There'}]
# Total
# Sample nr 13
# {'customer': 'cust13', 'customertime': 140.58979232319777, 'address': 'Here'}
# [{'customer': 'cust13', 'customertime': 140.58979232319777, 'address': 'Here'}, {'customer': 'cust13', 'customertime': 6831.134711062736, 'address': 'There'}]
# Total
# Sample nr 14
# {'customer': 'cust14', 'customertime': 75.81761735083865, 'address': 'Here'}
# [{'customer': 'cust14', 'customertime': 75.81761735083865, 'address': 'Here'}]
# Total
# Sample nr 15
# {'customer': 'cust15', 'customertime': 3.576439609915634, 'address': 'Here'}
# [{'customer': 'cust15', 'customertime': 3.576439609915634, 'address': 'Here'}]
# Total
# Sample nr 16
# {'customer': 'cust16', 'customertime': 44.23589545828163, 'address': 'Here'}
# [{'customer': 'cust16', 'customertime': 44.23589545828163, 'address': 'Here'}, {'customer': 'cust16', 'customertime': 6291.529372032738, 'address': 'There'}]
# Total
# Sample nr 17
# {'customer': 'cust17', 'customertime': 7.743095639324093, 'address': 'Here'}
# [{'customer': 'cust17', 'customertime': 7.743095639324093, 'address': 'Here'}]
# Total
# Sample nr 18
# {'customer': 'cust18', 'customertime': 54.1881320291586, 'address': 'Here'}
# [{'customer': 'cust18', 'customertime': 54.1881320291586, 'address': 'Here'}, {'customer': 'cust18', 'customertime': 3673.683366214693, 'address': 'There'}]
# Total
# Sample nr 19
# {'customer': 'cust19', 'customertime': 193.4098874547518, 'address': 'Here'}
# [{'customer': 'cust19', 'customertime': 193.4098874547518, 'address': 'Here'}, {'customer': 'cust19', 'customertime': 929.282564170169, 'address': 'There'}]
# Total
# Sample nr 20
# {'customer': 'cust20', 'customertime': 3.3003716176913853, 'address': 'Here'}
# [{'customer': 'cust20', 'customertime': 3.3003716176913853, 'address': 'Here'}]
# Total
# Sample nr 21
# {'customer': 'cust21', 'customertime': 134.90987232271013, 'address': 'Here'}
# [{'customer': 'cust21', 'customertime': 134.90987232271013, 'address': 'Here'}, {'customer': 'cust21', 'customertime': 1582.7168970258244, 'address': 'There'}]
# Total

# %%
from kafka import KafkaConsumer
consumer = KafkaConsumer('customer1',bootstrap_servers=['10.101.12.4:9092'],auto_offset_reset='earliest')
consumer.subscribe(['customer1'])
for message in consumer:
    print (message)
# Out:
# ConsumerRecord(topic='customer1', partition=3, offset=0, timestamp=1512123242055, timestamp_type=0, key=b'7', value=b'{"customer": "cust7", "customertime": 10.379287120516807, "address": "Here"}', checksum=-1255130703, serialized_key_size=1, serialized_value_size=76)
# ConsumerRecord(topic='customer1', partition=3, offset=1, timestamp=1512123242505, timestamp_type=0, key=b'1', value=b'{"customer": "cust1", "customertime": 22.19551732337296, "address": "Here"}', checksum=1735297947, serialized_key_size=1, serialized_value_size=75)
# ConsumerRecord(topic='customer1', partition=0, offset=0, timestamp=1512123242511, timestamp_type=0, key=b'2', value=b'{"customer": "cust2", "customertime": 49.77226732022002, "address": "Here"}', checksum=960699871, serialized_key_size=1, serialized_value_size=75)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-836450dd444c> in <module>()
#       2 consumer = KafkaConsumer('customer1',bootstrap_servers=['10.101.12.4:9092'],auto_offset_reset='earliest')
#       3 consumer.subscribe(['customer1'])
# ----> 4 for message in consumer:
#       5     print (message)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/consumer/group.py in __next__(self)
#    1073         self._set_consumer_timeout()
#    1074         try:
# -> 1075             return next(self._iterator)
#    1076         except StopIteration:
#    1077             self._iterator = None
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/consumer/group.py in _message_generator(self)
#    1011             if not self._fetcher.in_flight_fetches():
#    1012                 poll_ms = 0
# -> 1013             self._client.poll(timeout_ms=poll_ms)
#    1014
#    1015             # We need to make sure we at least keep up with scheduled tasks,
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/client_async.py in poll(self, timeout_ms, future, delayed_tasks)
#     552                 timeout = max(0, timeout / 1000.0)  # avoid negative timeouts
#     553
# --> 554             responses.extend(self._poll(timeout))
#     555
#     556             # If all we had was a timeout (future is None) - only do one poll
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/client_async.py in _poll(self, timeout)
#     566
#     567         start_select = time.time()
# --> 568         ready = self._selector.select(timeout)
#     569         end_select = time.time()
#     570         if self._sensors:
#
# /anaconda/envs/py35/lib/python3.5/selectors.py in select(self, timeout)
#     439             ready = []
#     440             try:
# --> 441                 fd_event_list = self._epoll.poll(timeout, max_ev)
#     442             except InterruptedError:
#     443                 return ready
#
# KeyboardInterrupt:

# %%
from kafka import KafkaConsumer
consumer = KafkaConsumer('policy1',bootstrap_servers=['10.101.12.4:9092'],auto_offset_reset='earliest')
consumer.subscribe(['policy1'])
for message in consumer:
    print (message)
# Out:
# ConsumerRecord(topic='policy1', partition=0, offset=0, timestamp=1512123242489, timestamp_type=0, key=b'7', value=b'{"pvar0": 2, "policystarttime": 10.379287120516807, "policyendtime": 3206.752895181903, "policy": 7, "pvar1": 7}', checksum=-1116527673, serialized_key_size=1, serialized_value_size=112)
# ConsumerRecord(topic='policy1', partition=0, offset=1, timestamp=1512123242505, timestamp_type=0, key=b'1', value=b'{"pvar0": 0, "policystarttime": 22.19551732337296, "policyendtime": 1377.3718059501339, "policy": 1, "pvar1": 2}', checksum=-1682797537, serialized_key_size=1, serialized_value_size=112)
# ConsumerRecord(topic='policy1', partition=0, offset=2, timestamp=1512123242511, timestamp_type=0, key=b'2', value=b'{"pvar0": 2, "policystarttime": 49.77226732022002, "policyendtime": 2065.191198319574, "policy": 2, "pvar1": 0}', checksum=-1571032798, serialized_key_size=1, serialized_value_size=111)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-81be8a28d1e5> in <module>()
#       2 consumer = KafkaConsumer('policy1',bootstrap_servers=['10.101.12.4:9092'],auto_offset_reset='earliest')
#       3 consumer.subscribe(['policy1'])
# ----> 4 for message in consumer:
#       5     print (message)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/consumer/group.py in __next__(self)
#    1073         self._set_consumer_timeout()
#    1074         try:
# -> 1075             return next(self._iterator)
#    1076         except StopIteration:
#    1077             self._iterator = None
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/consumer/group.py in _message_generator(self)
#    1011             if not self._fetcher.in_flight_fetches():
#    1012                 poll_ms = 0
# -> 1013             self._client.poll(timeout_ms=poll_ms)
#    1014
#    1015             # We need to make sure we at least keep up with scheduled tasks,
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/client_async.py in poll(self, timeout_ms, future, delayed_tasks)
#     552                 timeout = max(0, timeout / 1000.0)  # avoid negative timeouts
#     553
# --> 554             responses.extend(self._poll(timeout))
#     555
#     556             # If all we had was a timeout (future is None) - only do one poll
#
# /anaconda/envs/py35/lib/python3.5/site-packages/kafka/client_async.py in _poll(self, timeout)
#     566
#     567         start_select = time.time()
# --> 568         ready = self._selector.select(timeout)
#     569         end_select = time.time()
#     570         if self._sensors:
#
# /anaconda/envs/py35/lib/python3.5/selectors.py in select(self, timeout)
#     439             ready = []
#     440             try:
# --> 441                 fd_event_list = self._epoll.poll(timeout, max_ev)
#     442             except InterruptedError:
#     443                 return ready
#
# KeyboardInterrupt:

# %%
from kafka import KafkaConsumer
consumer = KafkaConsumer('pertest',bootstrap_servers=['10.101.12.4:9092'],auto_offset_reset='earliest')
consumer.subscribe(['claim'])
for message in consumer:
    print (message)
